# %%
import numpy as np
import pandas as pd
df=pd.read_csv('winequality.csv')
df
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     white            7.0             0.270         0.36            20.7
# 1     white            6.3             0.300         0.34             1.6
# 2     white            8.1             0.280         0.40             6.9
# 3     white            7.2             0.230         0.32             8.5
# 4     white            7.2             0.230         0.32             8.5
# ...     ...            ...               ...          ...             ...
# 6492    red            6.2             0.600         0.08             2.0
# 6493    red            5.9             0.550         0.10             2.2
# 6494    red            6.3             0.510         0.13             2.3
# 6495    red            5.9             0.645         0.12             2.0
# 6496    red            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   type                  6497 non-null   object
#  1   fixed acidity         6487 non-null   float64
#  2   volatile acidity      6489 non-null   float64
#  3   citric acid           6494 non-null   float64
#  4   residual sugar        6495 non-null   float64
#  5   chlorides             6495 non-null   float64
#  6   free sulfur dioxide   6497 non-null   float64
#  7   total sulfur dioxide  6497 non-null   float64
#  8   density               6497 non-null   float64
#  9   pH                    6488 non-null   float64
#  10  sulphates             6493 non-null   float64
#  11  alcohol               6497 non-null   float64
#  12  quality               6497 non-null   int64
# dtypes: float64(11), int64(1), object(1)
# memory usage: 660.0+ KB

# %%
df[df['fixed acidity'].isna()]
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 17    white            NaN             0.660         0.48             1.2
# 174   white            NaN             0.270         0.31            17.7
# 249   white            NaN             0.410         0.14            10.4
# 267   white            NaN             0.580         0.07             6.9
# 368   white            NaN             0.290         0.48             2.3
# 518   white            NaN             0.130         0.28             1.9
# 1079  white            NaN               NaN         0.29             6.2
# 2902  white            NaN             0.360         0.14             8.9
# 6428    red            NaN             0.440         0.09             2.2
# 6429    red            NaN             0.705         0.10             2.8
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 17        0.029                 29.0                  75.0  0.98920  3.33
# ...

# %%
#fixed acidity sütununu her şarap tipinin ortalamasına göre nan değerleri dolduralım
df['fixed acidity'] = df.groupby('type')['fixed acidity'].apply(lambda x: x.fillna(x.mean()))

# %%
df[df['volatile acidity'].isna()]
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 86    white       7.200000               NaN         0.63            11.0
# 521   white       7.900000               NaN         0.26             2.1
# 621   white       6.500000               NaN         0.43             8.9
# 812   white       6.400000               NaN         0.28             1.1
# 1079  white       6.855532               NaN         0.29             6.2
# 2894  white       6.400000               NaN         0.36             1.4
# 4895  white       6.500000               NaN         0.19             1.2
# 6486    red       7.200000               NaN         0.33             2.5
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 86        0.044                 55.0                 156.0  0.99740  3.09
# 521       0.039                  8.0                 143.0  0.99420  3.05
# 621       0.083                 50.0                 171.0  0.99650  2.85
# ...

# %%
#volatile acidity sütununu her şarap tipinin ortalamasına göre nan değerleri dolduralım
df['volatile acidity'] = df.groupby('type')['volatile acidity'].apply(lambda x: x.fillna(x.mean()))

# %%
df[df['citric acid'].isna()]
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 268   white            5.3             0.585          NaN             7.1
# 909   white            7.5             0.240          NaN            13.0
# 6320    red            7.0             0.540          NaN             2.1
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 268       0.044                 34.0                 145.0   0.9945  3.34
# 909       0.049                 46.0                 217.0   0.9985  3.08
# 6320      0.079                 39.0                  55.0   0.9956  3.39
#
#       sulphates  alcohol  quality
# 268        0.57      9.7        6
# 909        0.53      8.8        5
# 6320       0.84     11.4        6

# %%
#citric acid sütununu her şarap tipinin ortalamasına göre nan değerleri dolduralım
df['citric acid'] = df.groupby('type')['citric acid'].apply(lambda x: x.fillna(x.mean()))

# %%
df[df['residual sugar'].isna()]
# Out:
#       type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 33   white            6.2             0.120         0.34             NaN
# 438  white            7.4             0.155         0.34             NaN
#
#      chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 33       0.045                 43.0                 117.0   0.9939  3.42
# 438      0.045                 73.5                 214.0   0.9934  3.18
#
#      sulphates  alcohol  quality
# 33        0.51      9.0        6
# 438       0.61      9.9        7

# %%
#residual sugar sütununu her şarap tipinin ortalamasına göre nan değerleri dolduralım
df['residual sugar']=df['residual sugar'].fillna(df[df['type']=='white']['residual sugar'].mean())

# %%
df[df['chlorides'].isna()]
# Out:
#       type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 98   white            9.8              0.36         0.46            10.5
# 747  white            7.2              0.29         0.40             7.6
#
#      chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 98         NaN                  4.0                  83.0   0.9956  2.89
# 747        NaN                 56.0                 177.0   0.9928  3.04
#
#      sulphates  alcohol  quality
# 98        0.30     10.1        4
# 747       0.32     11.5        6

# %%
#chlorides sütununu her şarap tipinin ortalamasına göre nan değerleri dolduralım
df['chlorides']=df['chlorides'].fillna(df[df['type']=='white']['chlorides'].mean())

# %%
df[df['pH'].isna()]
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 54    white       6.800000             0.200         0.59             0.9
# 139   white       8.100000             0.280         0.39             1.9
# 440   white       6.700000             0.220         0.37             1.6
# 587   white       6.100000             0.320         0.25             1.7
# 697   white       7.500000             0.310         0.51            14.8
# 972   white       6.800000             0.220         0.35            17.5
# 4892  white       6.500000             0.230         0.38             1.3
# 6428    red       8.322104             0.440         0.09             2.2
# 6429    red       8.322104             0.705         0.10             2.8
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density  pH  \
# 54        0.147                 38.0                 132.0  0.99300 NaN
# 139       0.029                 18.0                  79.0  0.99230 NaN
# ...

# %%
#pH sütununu her şarap tipinin ortalamasına göre nan değerleri dolduralım
df['pH'] = df.groupby('type')['pH'].apply(lambda x: x.fillna(x.mean()))

# %%
df[df['sulphates'].isna()]
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 224   white       6.300000             0.495         0.22             1.8
# 2902  white       6.855532             0.360         0.14             8.9
# 6321    red       6.400000             0.530         0.09             3.9
# 6493    red       5.900000             0.550         0.10             2.2
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 224       0.046                 31.0                 140.0  0.99290  3.39
# 2902      0.036                 38.0                 155.0  0.99622  3.27
# 6321      0.123                 14.0                  31.0  0.99680  3.50
# 6493      0.062                 39.0                  51.0  0.99512  3.52
#
#       sulphates  alcohol  quality
# 224         NaN     10.4        6
# 2902        NaN      9.4        5
# 6321        NaN     11.0        4
# 6493        NaN     11.2        6

# %%
#sulphates sütununu her şarap tipinin ortalamasına göre nan değerleri dolduralım
df['sulphates'] = df.groupby('type')['sulphates'].apply(lambda x: x.fillna(x.mean()))

# %%
df.isna().sum()
# Out:
# type                    0
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['type'] = le.fit_transform(df['type'])
df
# Out:
#       type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        1            7.0             0.270         0.36            20.7
# 1        1            6.3             0.300         0.34             1.6
# 2        1            8.1             0.280         0.40             6.9
# 3        1            7.2             0.230         0.32             8.5
# 4        1            7.2             0.230         0.32             8.5
# ...    ...            ...               ...          ...             ...
# 6492     0            6.2             0.600         0.08             2.0
# 6493     0            5.9             0.550         0.10             2.2
# 6494     0            6.3             0.510         0.13             2.3
# 6495     0            5.9             0.645         0.12             2.0
# 6496     0            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import mean_squared_error
independent_variables=df.drop(['quality'], axis=1)
predict_value=df['quality']
X_train, X_test, y_train, y_test = train_test_split(independent_variables, predict_value, test_size=0.20, random_state=0)
logistic_classifier= LogisticRegression(random_state=0)  
logistic_classifier.fit(X_train, y_train)
y2=logistic_classifier.predict(X_train)
mse = mean_squared_error(y_train, y2)
mse
# Out:
# C:\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.7827592842024245

# %%
from sklearn.linear_model import LinearRegression
lr= LinearRegression()  
lr.fit(X_train, y_train)
y2=lr.predict(X_train)
mse = mean_squared_error(y_train, y2)
mse
# Out:
# 0.5385310425421873

# %%
import xgboost as xgb
xgbr = xgb.XGBRegressor(verbosity=0) 
xgbr.fit(X_train, y_train)
y2=xgbr.predict(X_train)
mse = mean_squared_error(y_train, y2)
mse
# Out:
# 0.07207959855290734

# %%
#6492. indeksteki şarabın değerlerini biraz değiştirip tek bir değere tahmin ettirmek istiyorum
index=[0]
veri_cercevesi = pd.DataFrame({'type': 0, 'fixed acidity': 6.1 , 'volatile acidity': 0.65, 'citric acid': 0.082, 'residual sugar': 2.1, 'chlorides': 0.1, 'free sulfur dioxide': 31.7, 'total sulfur dioxide': 43.1,
                  'density':0.995, 'pH': 3.42, 'sulphates': 0.55, 'alcohol': 10.7},index=index)
veri_cercevesi
# Out:
#    type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     0            6.1              0.65        0.082             2.1
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0        0.1                 31.7                  43.1    0.995  3.42
#
#    sulphates  alcohol
# 0       0.55     10.7

# %%
tahmin=xgbr.predict(veri_cercevesi)
tahmin
# Out:
# array([5.3567953], dtype=float32)
